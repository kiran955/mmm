# %% [markdown]
# # importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing data set

# %%
a=pd.read_csv('C:\\Users\\DELL\\Desktop\\data set-1 (2).csv')
a.head()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    id   type  sub_type  start_date    end_date  listing_type  tom  \
# 0   1  Konut  Rezidans  12-10-2018  01-09-2019             2   30
# 1   2  Konut     Daire     2/13/19         NaN             1   14
# 2   3  Konut     Daire  10-09-2018  11-08-2018             1   30
# 3   4  Konut  Rezidans  09-10-2018  10-10-2018             1   30
# 4   5  Konut  Rezidans  12-10-2018  01-09-2019             1   30
#
#   building_age total_floor_count  floor_no room_count   size  \
# 0            0       20 ve üzeri         2        2+1   90.0
# 1            0       20 ve üzeri         5        1+0   43.0
# 2            0                 1        33        2+1    NaN
# 3            3       20 ve üzeri         5        6+1  450.0
# ...

# %%
a['sub_type'].value_counts()
# Out:
# Daire                  354549
# Villa                   21324
# Müstakil Ev              9563
# Rezidans                 7716
# Yazlık                   5929
# Komple Bina              2607
# Prefabrik Ev              679
# Çiftlik Evi               528
# Köşk / Konak / Yalı       301
# Yalı Dairesi              187
# Kooperatif                 70
# Loft                       34
# Name: sub_type, dtype: int64

# %% [markdown]
# # drop the unnecessary varailbe in data set

# %%
k=a.drop(["address","furnished"],axis=1)

# %%
k.head()
# Out:
#    id   type  sub_type  start_date    end_date  listing_type  tom  \
# 0   1  Konut  Rezidans  12-10-2018  01-09-2019             2   30
# 1   2  Konut     Daire     2/13/19         NaN             1   14
# 2   3  Konut     Daire  10-09-2018  11-08-2018             1   30
# 3   4  Konut  Rezidans  09-10-2018  10-10-2018             1   30
# 4   5  Konut  Rezidans  12-10-2018  01-09-2019             1   30
#
#   building_age total_floor_count  floor_no room_count   size heating_type  \
# 0            0       20 ve üzeri         2        2+1   90.0      Fancoil
# 1            0       20 ve üzeri         5        1+0   43.0      Fancoil
# 2            0                 1        33        2+1    NaN      Fancoil
# 3            3       20 ve üzeri         5        6+1  450.0      Fancoil
# 4            0       20 ve üzeri         2        2+1   90.0      Fancoil
#
#         price price_currency
# 0      3500.0            TRY
# 1    490000.0            TRY
# 2    155000.0            TRY
# ...

# %%
k.shape
# Out:
# (403487, 15)

# %% [markdown]
# # finding the duplicate values in data set

# %%
k.duplicated().sum()
# Out:
# 0

# %%
k.isnull().sum()
# Out:
# id                        0
# type                      0
# sub_type                  0
# start_date                0
# end_date             137189
# listing_type              0
# tom                       0
# building_age          27390
# total_floor_count     28021
# floor_no                  0
# room_count                0
# size                 146006
# heating_type          27970
# price                   715
# price_currency          715
# dtype: int64

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403487 entries, 0 to 403486
# Data columns (total 15 columns):
# id                   403487 non-null int64
# type                 403487 non-null object
# sub_type             403487 non-null object
# start_date           403487 non-null object
# end_date             266298 non-null object
# listing_type         403487 non-null int64
# tom                  403487 non-null int64
# building_age         376097 non-null object
# total_floor_count    375466 non-null object
# floor_no             403487 non-null int64
# room_count           403487 non-null object
# size                 257481 non-null float64
# heating_type         375517 non-null object
# price                402772 non-null float64
# price_currency       402772 non-null object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 46.2+ MB

# %% [markdown]
# # filling the null values using  with a backward method

# %%
k.fillna(method='bfill')
# Out:
#             id   type     sub_type  start_date    end_date  listing_type  tom  \
# 0            1  Konut     Rezidans  12-10-2018  01-09-2019             2   30
# 1            2  Konut        Daire     2/13/19  11-08-2018             1   14
# 2            3  Konut        Daire  10-09-2018  11-08-2018             1   30
# 3            4  Konut     Rezidans  09-10-2018  10-10-2018             1   30
# 4            5  Konut     Rezidans  12-10-2018  01-09-2019             1   30
# 5            6  Konut     Rezidans  11-09-2018  12-09-2018             1   30
# 6            7  Konut        Daire  01-04-2019  01-03-2019             2   54
# 7            8  Konut        Villa  10-03-2018  01-03-2019             1   92
# 8            9  Konut        Daire     2/16/19    12/26/18             1   11
# 9           10  Konut        Daire    12/26/18    12/26/18             1    0
# 10          11  Konut  Müstakil Ev    11/13/18    11/26/18             1   13
# ...

# %%
k.isnull().sum()
# Out:
# id                        0
# type                      0
# sub_type                  0
# start_date                0
# end_date             137189
# listing_type              0
# tom                       0
# building_age          27390
# total_floor_count     28021
# floor_no                  0
# room_count                0
# size                 146006
# heating_type          27970
# price                   715
# price_currency          715
# dtype: int64

# %%
a.isnull().sum()
# Out:
# id                        0
# type                      0
# sub_type                  0
# start_date                0
# end_date             137189
# listing_type              0
# tom                       0
# building_age          27390
# total_floor_count     28021
# floor_no                  0
# room_count                0
# size                 146006
# address                   0
# furnished            403487
# heating_type          27970
# price                   715
# price_currency          715
# dtype: int64

# %%
k.isnull().sum()
# Out:
# id                        0
# type                      0
# sub_type                  0
# start_date                0
# end_date             137189
# listing_type              0
# tom                       0
# building_age          27390
# total_floor_count     28021
# floor_no                  0
# room_count                0
# size                 146006
# heating_type          27970
# price                   715
# price_currency          715
# dtype: int64

# %%
ad=k.fillna(method="bfill")
ad.head()
# Out:
#    id   type  sub_type  start_date    end_date  listing_type  tom  \
# 0   1  Konut  Rezidans  12-10-2018  01-09-2019             2   30
# 1   2  Konut     Daire     2/13/19  11-08-2018             1   14
# 2   3  Konut     Daire  10-09-2018  11-08-2018             1   30
# 3   4  Konut  Rezidans  09-10-2018  10-10-2018             1   30
# 4   5  Konut  Rezidans  12-10-2018  01-09-2019             1   30
#
#   building_age total_floor_count  floor_no room_count   size heating_type  \
# 0            0       20 ve üzeri         2        2+1   90.0      Fancoil
# 1            0       20 ve üzeri         5        1+0   43.0      Fancoil
# 2            0                 1        33        2+1  450.0      Fancoil
# 3            3       20 ve üzeri         5        6+1  450.0      Fancoil
# 4            0       20 ve üzeri         2        2+1   90.0      Fancoil
#
#         price price_currency
# 0      3500.0            TRY
# 1    490000.0            TRY
# 2    155000.0            TRY
# ...

# %%
n=ad.fillna(method='ffill')

# %%
n.isnull().sum()
# Out:
# id                   0
# type                 0
# sub_type             0
# start_date           0
# end_date             0
# listing_type         0
# tom                  0
# building_age         0
# total_floor_count    0
# floor_no             0
# room_count           0
# size                 0
# heating_type         0
# price                0
# price_currency       0
# dtype: int64

# %%
n.head()
# Out:
#    id   type  sub_type  start_date    end_date  listing_type  tom  \
# 0   1  Konut  Rezidans  12-10-2018  01-09-2019             2   30
# 1   2  Konut     Daire     2/13/19  11-08-2018             1   14
# 2   3  Konut     Daire  10-09-2018  11-08-2018             1   30
# 3   4  Konut  Rezidans  09-10-2018  10-10-2018             1   30
# 4   5  Konut  Rezidans  12-10-2018  01-09-2019             1   30
#
#   building_age total_floor_count  floor_no room_count   size heating_type  \
# 0            0       20 ve üzeri         2        2+1   90.0      Fancoil
# 1            0       20 ve üzeri         5        1+0   43.0      Fancoil
# 2            0                 1        33        2+1  450.0      Fancoil
# 3            3       20 ve üzeri         5        6+1  450.0      Fancoil
# 4            0       20 ve üzeri         2        2+1   90.0      Fancoil
#
#         price price_currency
# 0      3500.0            TRY
# 1    490000.0            TRY
# 2    155000.0            TRY
# ...

# %%
n.isnull().sum()
# Out:
# id                   0
# type                 0
# sub_type             0
# start_date           0
# end_date             0
# listing_type         0
# tom                  0
# building_age         0
# total_floor_count    0
# floor_no             0
# room_count           0
# size                 0
# heating_type         0
# price                0
# price_currency       0
# dtype: int64

# %% [markdown]
# # finding the range of the min and max with particular variables

# %%
range=max(n['size'])-min(n['size'])

# %%
range
# Out:
# 948234.0

# %%
max(n["size"])
# Out:
# 948235.0

# %%
n.describe()
# Out:
#                  id   listing_type            tom       floor_no  \
# count  403487.00000  403487.000000  403487.000000  403487.000000
# mean   201744.00000       1.294235      57.022739      22.481936
# std    116476.80837       0.467733      44.358933       3.719082
# min         1.00000       1.000000       0.000000       1.000000
# 25%    100872.50000       1.000000      29.000000      22.000000
# 50%    201744.00000       1.000000      40.000000      22.000000
# 75%    302615.50000       2.000000      90.000000      22.000000
# max    403487.00000       3.000000     180.000000      35.000000
#
#                 size         price
# count  403487.000000  4.034870e+05
# mean      281.472915  3.545662e+05
# std      9486.534360  4.805358e+06
# min         1.000000 -2.500000e+02
# 25%        85.000000  2.500000e+03
# 50%       110.000000  1.990000e+05
# 75%       140.000000  3.400000e+05
# max    948235.000000  2.000000e+09

# %%
min(n["size"])
# Out:
# 1.0

# %%
a['floor_no'].unique()
# Out:
# array([ 2,  5, 33, 10, 14, 35, 28, 21, 22, 11,  3, 13,  7, 16, 31, 34, 19,
#         4,  1,  8, 27, 29,  6, 25, 24, 15,  9, 30, 20, 12, 17, 23, 26, 32,
#        18], dtype=int64)

# %% [markdown]
# # individually finding the max and min

# %%
b=min(n["size"]),max(n["size"])

# %%
b
# Out:
# (1.0, 948235.0)

# %% [markdown]
# # finding the type of the categories in data set

# %%
a['type'].unique()
# Out:
# array(['Konut'], dtype=object)

# %% [markdown]
# # visulization for plots

# %%
sns.boxplot(data=n)

# %%
plt.figure(figsize=(6,6))
n.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A1105280B8>,
# ...
#       dtype=object)

# %%
sns.boxplot(data=n)

# %%
sns.catplot(x="sub_type",y="price",data=n,kind="bar",height=10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # heat map

# %%
plt.figure(figsize=(10,10))
sns.heatmap(n.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %%
a['heating_type'].unique()
# Out:
# array(['Fancoil', 'Yok', 'Kalorifer (Doğalgaz)', 'Kalorifer (Kömür)',
#        'Kombi (Elektrikli)', 'Klima', 'Kombi (Doğalgaz)',
#        'Merkezi Sistem (Isı Payı Ölçer)', 'Merkezi Sistem',
#        'Soba (Kömür)', 'Yerden Isıtma', 'Soba (Doğalgaz)',
#        'Güneş Enerjisi', 'Kalorifer (Akaryakıt)', 'Jeotermal',
#        'Kat Kaloriferi', nan], dtype=object)

# %% [markdown]
# # Appliyng label encoding

# %%
#from sklearn.preprocessing import LabelEncoder
#r=LabelEncoder()
#n['heating_type']=r.fit_transform(n['heating_type'])

# %%
#n['total_floor_count']=r.fit_transform(n['total_floor_count'])

# %%
#n['sub_type']=r.fit_transform(n['sub_type'])

# %%
#n['floor_no']=r.fit_transform(n['floor_no'])

# %%
#n['floor_no'].tail()

# %%
#n['floor_no']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.scatterplot(x='sub_type',y='price',data=n)

# %% [markdown]
# # pie chart

# %%
explode=[0,0.1]
plt.figure(figsize=(20,22))
n['sub_type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # count chart

# %%
plt.figure(figsize=(10,12))
plt.xticks(rotation=90)
sns.countplot(n['sub_type'])

# %%
plt.figure(figsize=(5,10))
sns.factorplot(x='room_count',y='price',data=n)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.stripplot(x="sub_type",y="price",data=n)
plt.show()
